# %% [markdown]
# ### Convert from screenshots to name and png to jpg

# %% [markdown]
# All files must be .jpg. So convert img from .png to .jpg and add it new UUID name, and rename .xml depend on new UUID name. So new img name corresponds with new .xml

# %%
# !pip install opencv-python==4.5.4.58
# Out:
# ...
#      |████████████████████████████████| 60.3 MB 43.7 MB/s
# ...
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
from utils.imageConverter import ImageConverter

imgConverter = ImageConverter()
imgConverter.load_images_from_folder()
# Out:
# []

# %% [markdown]
# ### Convert all xml VOC to Yolo5 annotation

# %% [markdown]
# Take all xml files, which are VOC annotation and convert it into Yolo5 annotation.

# %%
from utils.xmlYoloConverter import XmlYoloConverter

converter = XmlYoloConverter()
# param directory to convert
converter.convert_all_xml_in_directory_to_yolo5('dataset')
# Out:
#   7%|▋         | 29/399 [00:00<00:01, 282.17it/s]Try to save new .txt with name: dataset/Snímek obrazovky 2021-10-25 v 15.55.35.png
# Try to save new .txt with name: dataset/013BECE5A9.txt
# Try to save new .txt with name: dataset/016EB11CFF.txt
# Try to save new .txt with name: dataset/Snímek obrazovky 2021-10-25 v 15.50.11.png
# Try to save new .txt with name: dataset/01B5C4D37E.txt
# Try to save new .txt with name: dataset/02B94E1954.txt
# Try to save new .txt with name: dataset/04DB49DB65.txt
# Try to save new .txt with name: dataset/05147FBB97.txt
# Try to save new .txt with name: dataset/Snímek obrazovky 2021-10-25 v 15.25.07.png
# Try to save new .txt with name: dataset/065463125D.txt
# Try to save new .txt with name: dataset/0710049FB5.txt
# Try to save new .txt with name: dataset/Snímek obrazovky 2021-10-25 v 15.23.21.png
# Try to save new .txt with name: dataset/07982DF866.txt
# Try to save new .txt with name: dataset/086D5DC1B9.txt
# ...

# %% [markdown]
# ### Demo bounding box draw

# %% [markdown]
# Take one picture and annotation and draw bounding box into image from yolo annotation. Is annotation ok ? Are rectangles in good position, to predict objects ?

# %%
from utils.imageBoundingBoxShower import ImageBoundingBoxShower

shower = ImageBoundingBoxShower()
shower.draw_bounding_box_by_yolo_annotation()

# %% [markdown]
# ### Split training and validation size to directories

# %% [markdown]
# Split data with annotations into directories, with specific size. Default training size is 0.7 and validation is 0.2. Use constructor to define different size of data -&gt; DataPartitioner(test_size=0.5, validation_size=0.3)

# %%
from utils.datasetPartitioner import DatasetPartitioner

partitioner = DatasetPartitioner(train_size=0.7, validation_size=0.2)
partitioner.partition_dataset_to_test_and_train_packages()
# Out:
# Cheching for required directories...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-861c1d74ae9a> in <module>
#       2
#       3 partitioner = DatasetPartitioner(train_size=0.7, validation_size=0.2)
# ----> 4 partitioner.partition_dataset_to_test_and_train_packages()
#
# /work/PAN_OCR/utils/datasetPartitioner.py in partition_dataset_to_test_and_train_packages(self)
#      38         annotations.sort()
#      39         # Split the dataset into train-valid-test splits
# ---> 40         train_images, val_images, train_annotations, val_annotations = train_test_split(images, annotations, test_size = 0.5, random_state = 1)
#      41         val_images, test_images, val_annotations, test_annotations = train_test_split(val_images, val_annotations, test_size = 0.2, random_state = 1)
#      42
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b7ee9ef1-a2d4-4879-82a0-eccfcea8e852' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
